# %%
import pandas as pd

# %%
df = pd.read_csv("cleaned_data_combined_modified.csv")

# %%
from cleanDataQ3Q6 import *
# Out:
# carbonated drink
# gingerale
# the avengers
# no drink
# jarritos
# carbonated drinks
# fish sauce
# no drink
# no drink
# none
# korea drinkjapanese drink
# any drink works well
# sprindrift
# gingerale
# any drink would pair well
# laban
# gingerale
# no drink
# laban
# yogurt
# soft
# i have no idea i dont eat that stuff
# no drink
# dairy
# no drink
# ...

# %%
df.head()
# Out:
#        id  \
# 0  716549
# 1  715742
# 2  727333
# 3  606874
# 4  505318
#
#    Q1: From a scale 1 to 5, how complex is it to make this food? (Where 1 is the most simple, and 5 is the most complex)  \
# 0                                                  3
# 1                                                  4
# 2                                                  3
# 3                                                  4
# 4                                                  2
#
#   Q2: How many ingredients would you expect this food item to contain?  \
# 0                                                  6
# 1                                        bread, meet
# 2                                                  5
# 3                                              7-Jun
# 4                                          3 or more
#
#   Q3: In what setting would you expect this food to be served? Please check all that apply  \
# 0         Week day lunch,At a party,Late night snack
# ...

# %%
q6_col = "Q6: What drink would you pair with this food item?"

df["Q6_cleaned"] = df_test['Q6: What drink would you pair with this food item?'].apply(map_drink)
df[[q6_col, "Q6_cleaned", "Label"]].head()
# Out:
#   Q6: What drink would you pair with this food item? Q6_cleaned  Label
# 0                                          coca-cola  coca-cola  Pizza
# 1                                          coca-cola  coca-cola  Pizza
# 2                                          coca-cola  coca-cola  Pizza
# 3                                               soda       soda  Pizza
# 4                                               soda  coca-cola  Pizza
